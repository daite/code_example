# %%
import pandas as pd; import numpy as np
from pandas import DataFrame, Series
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
fig, axes = plt.subplots(2,2)
ax1 = axes[0,0]
ax2 = axes[0,1]
ax3 = axes[1,0]
ax4 = axes[1,1]
ax1.plot(np.random.randn(100).cumsum(), color='purple', label='ax1', marker='o')
ax1.legend(loc='best')
ax2.plot(np.random.randn(100).cumsum(), color='blue', label='ax2', marker='.')
ax2.legend(loc='best')
ax3.plot(np.random.randn(100).cumsum(), color='red', label='ax3', marker='>')
ax3.legend(loc='best')
ax4.plot(np.random.randn(100).cumsum(), color='green', label='ax4', alpha=0.7,
        marker='<')
ax4.legend(loc='best')
# Out:
# <img src="data:image/png;base64,...">

# %%
df = pd.read_csv('data.csv', encoding='shift-jis', skiprows=3).dropna()

# %%
#http://stackoverflow.com/questions/23197124/display-non-ascii-japanese-characters-in-pandas-plot-legend
import matplotlib
import matplotlib.font_manager as fm
df.index = pd.to_datetime(df['年月日'])
df2 = df.ix[:, [1,2,3]]

date_range_2013 = pd.date_range('2013-06-01', '2013-09-01', freq='D')
date_range_2014 = pd.date_range('2014-06-01', '2014-09-01', freq='D')
date_range_2015 = pd.date_range('2015-06-01', '2015-09-01', freq='D')

_, axes = plt.subplots(3,1)
date_range = [date_range_2013, date_range_2014, date_range_2015]
for n, date in enumerate(date_range):
    df2.loc[date].plot(ax=axes[n], marker='o', grid=True)
font = fm.FontProperties(fname='/Users/chris/Desktop/ipaexm.ttf')
for ax in [axes[0], axes[1], axes[2]]:
    legend = ax.legend(loc='best')
    for text in legend.texts:
        text.set_font_properties(font)
# Out:
# <img src="data:image/png;base64,...">
